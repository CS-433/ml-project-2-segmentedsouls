# %%
#MIP
import matplotlib.pyplot as plt
epoch_values=[10,50,100, 500, 690]

loss_train_lr2=[0.4452, 0.3279,0.3008,0.1945,0.1682]
loss_test_lr2=[0.9540,0.8341,0.8340,0.9439,0.9819]


loss_train_lr1=[0.4214,0.3320,0.3010,0.2094,0.1828]
loss_test_lr1=[0.8714,0.8172,0.8236,0.8975,0.9079]

loss_train_lr01=[0.4909,0.3827,0.3563,0.2897,0.2584]
loss_test_lr01=[0.8187,0.8280,0.8005,0.8345,0.8272]


loss_train_lr001=[0.5929,0.4639,0.4255,0.3888,0.3572]
loss_test_lr001=[0.8336,0.8725,0.8421,0.8265,0.8200]





plt.plot(epoch_values, loss_train_lr001, label='lr=0.001')
plt.plot(epoch_values,loss_train_lr01, label='lr=0.01')
plt.plot(epoch_values,loss_train_lr1, label='lr=0.1')
plt.plot(epoch_values, loss_train_lr2, label='lr=0.2')


plt.xlabel('Number of Epochs')
plt.ylabel('Loss')
plt.title('MIP: Training loss')
plt.legend()
plt.show()

# %%
plt.plot(epoch_values, loss_test_lr001, label='lr=0.001')
plt.plot(epoch_values,loss_test_lr01, label='lr=0.01')
plt.plot(epoch_values,loss_test_lr1, label='lr=0.1')
plt.plot(epoch_values, loss_test_lr2, label='lr=0.2')

plt.xlabel('Number of Epochs')
plt.ylabel('Loss')
plt.title('Mip: test loss')
plt.legend()

plt.show()

# %%
#FOCUS images 
epoch_values=[10,50,100, 500, 690]

foc_loss_train_lr2=[0.2931,0.1961,0.1583,0.1162,0.0992]
foc_loss_test_lr2=[1.3691,1.5310,1.5454,1.6124,1.7367]


foc_loss_train_lr1=[0.3084,0.2007,0.1667,0.1328,0.1147]
foc_loss_test_lr1=[1.2940,1.5448,1.5579,1.5731,1.6504]

foc_loss_train_lr01=[0.3815,0.2650,0.2279,0.1793,0.1689]
foc_loss_test_lr01=[1.1652,1.3557,1.3948,1.4708,1.4645]


foc_loss_train_lr001=[0.4054,0.3478,0.3126,0.2520,0.2453]
foc_loss_test_lr001=[1.1566,1.2570,1.2964,1.3468,1.3426]





plt.plot(epoch_values, foc_loss_train_lr001, label='lr=0.001')
plt.plot(epoch_values,foc_loss_train_lr01, label='lr=0.01')
plt.plot(epoch_values,foc_loss_train_lr1, label='lr=0.1')
plt.plot(epoch_values, foc_loss_train_lr2, label='lr=0.2')


plt.xlabel('Number of Epochs')
plt.ylabel('Loss')
plt.title('Focus: Training loss')
plt.legend()
plt.show()

# %%
plt.plot(epoch_values, foc_loss_test_lr001, label='lr=0.001')
plt.plot(epoch_values,foc_loss_test_lr01, label='lr=0.01')
plt.plot(epoch_values,foc_loss_test_lr1, label='lr=0.1')
plt.plot(epoch_values, foc_loss_test_lr2, label='lr=0.2')


plt.xlabel('Number of Epochs')
plt.ylabel('Loss')
plt.title('Focus: Test loss')
plt.legend()
plt.show()
